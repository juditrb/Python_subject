# %%
with open('sequence_fragments.txt', 'r') as file:
    subseqdic = {}
    for line in file:
        subseqdic[line.strip()] = 0

# %%
len(subseqdic.keys())
# Out:
# 241

# %%
with open('example_fasta_file.fa', 'r') as fd:
    fastaf = fd.read().split('>')[1:]
    proteins = ["".join(protein.split("\n")[1:]) for protein in fastaf]

# %%
for protein in proteins:
    for subseq in subseqdic.keys():
        if protein.count(subseq) >= 3:
            subseqdic[subseq] += 1

# %%
total_proteins = len(proteins)

# %%
sorted_subseqdic = dict(sorted(subseqdic.items(), key=lambda x:x[1], reverse=True))

# %%
with open('output.txt', 'w') as out_file:
        out_file.write(f"#Number of proteins: {total_proteins:>{43}}\n")
        out_file.write(f"#Number of subsequences: {len(subseqdic.keys()):>{39}}\n")
        out_file.write("#Subsequence proportions:\n")
        for subseq, count in sorted_subseqdic.items():
            proportion = round(count / total_proteins, 4)
            out_file.write(f"{subseq} {count:>{20}} {proportion:>{40}}\n")

# %%
dict(sorted_subseqdic)
# Out:
# {'EL': 45,
#  'IL': 45,
#  'LV': 43,
#  'VK': 42,
#  'PE': 41,
#  'VL': 41,
#  'LA': 40,
#  'LT': 39,
#  'RL': 39,
#  'IS': 37,
#  'LP': 37,
#  'SV': 37,
#  'GA': 36,
#  'TL': 36,
#  'VA': 36,
#  'GT': 34,
#  'VS': 34,
#  'GS': 33,
#  'DS': 31,
#  'KD': 31,
#  'DP': 30,
#  'FG': 30,
#  'KR': 30,
#  'PT': 30,
#  'RD': 30,
#  'RE': 30,
#  'DF': 29,
#  'DG': 29,
#  'VG': 29,
#  'VP': 29,
#  'DA': 28,
#  'RG': 28,
#  'RR': 28,
#  'YL': 27,
#  'EG': 26,
#  'GP': 26,
#  'IV': 26,
#  'RS': 25,
#  'ST': 25,
#  'GI': 24,
#  'HL': 24,
#  'KT': 24,
#  'AF': 22,
#  'EY': 22,
#  'LY': 22,
#  'QV': 22,
#  'VQ': 22,
#  'IP': 20,
#  'KN': 20,
#  'QI': 20,
#  'TI': 19,
#  'IF': 17,
#  'KF': 17,
#  'NT': 17,
#  'QK': 17,
#  'TT': 17,
#  'YS': 16,
#  'FR': 15,
#  'CT': 14,
#  'KM': 14,
#  'ND': 14,
#  'FI': 13,
#  'MV': 12,
#  'MD': 11,
#  'AC': 10,
#  'NA': 10,
#  'VM': 8,
#  'FQ': 7,
#  'MT': 6,
#  'PC': 6,
#  'YQ': 6,
#  'RLL': 5,
#  'WV': 5,
#  'LAA': 4,
#  'LVE': 4,
#  'REL': 4,
#  'FGK': 3,
#  'GTQ': 3,
#  'ISK': 3,
#  'KFR': 3,
#  'SW': 3,
#  'YLD': 3,
#  'AFV': 2,
#  'DAC': 2,
#  'DGI': 2,
#  'DKPD': 2,
#  'DPS': 2,
#  'EGV': 2,
#  'EIEL': 2,
#  'ELI': 2,
#  'EPSE': 2,
#  'EYD': 2,
#  'FIS': 2,
#  'FRI': 2,
#  'GAL': 2,
#  'GGSD': 2,
#  'GPV': 2,
#  'GSN': 2,
#  'GTI': 2,
#  'HLR': 2,
#  'ILL': 2,
#  'IPE': 2,
#  'IVL': 2,
#  'KDE': 2,
#  'KFS': 2,
#  'KNT': 2,
#  'KRE': 2,
#  'KTE': 2,
#  'LPK': 2,
#  'LTD': 2,
#  'LYD': 2,
#  'LYP': 2,
#  'NTA': 2,
#  'PEH': 2,
#  'PEK': 2,
#  'QIK': 2,
#  'RDA': 2,
#  'RET': 2,
#  'RLD': 2,
#  'RRI': 2,
#  'STT': 2,
#  'SVR': 2,
#  'SWY': 2,
#  'TLE': 2,
#  'TLV': 2,
#  'TTY': 2,
#  'VAI': 2,
#  'VGR': 2,
#  'VKY': 2,
#  'VLI': 2,
#  'VPV': 2,
#  'VQL': 2,
#  'WK': 2,
#  'WVE': 2,
#  'YQK': 2,
#  'DSSD': 1,
#  'LVKD': 1,
#  'MVS': 1,
#  'NDK': 1,
#  'NTVS': 1,
#  'PQPK': 1,
#  'RGA': 1,
#  'VATA': 1,
#  'VMV': 1,
#  'VSF': 1,
#  'AAVP': 0,
#  'ACV': 0,
#  'AEAV': 0,
#  'AINP': 0,
#  'ALSV': 0,
#  'CGTG': 0,
#  'CITP': 0,
#  'CTD': 0,
#  'CVDW': 0,
#  'DFY': 0,
#  'DKED': 0,
#  'DKTI': 0,
#  'DRYF': 0,
#  'DSN': 0,
#  'DTDC': 0,
#  'EDPT': 0,
#  'EEYY': 0,
#  'EMMI': 0,
#  'ETAQ': 0,
#  'FALL': 0,
#  'FEPK': 0,
#  'FQD': 0,
#  'FQRE': 0,
#  'FQS': 0,
#  'FVAG': 0,
#  'FVNE': 0,
#  'GAT': 0,
#  'GEAC': 0,
#  'GIK': 0,
#  'HKTA': 0,
#  'HSGV': 0,
#  'IFN': 0,
#  'IGAT': 0,
#  'IKPL': 0,
#  'IPIV': 0,
#  'IQEM': 0,
#  'IQLR': 0,
#  'ISGP': 0,
#  'IVMD': 0,
#  'KAVE': 0,
#  'KAYN': 0,
#  'KIYT': 0,
#  'KML': 0,
#  'KNIT': 0,
#  'KTLY': 0,
#  'KVYD': 0,
#  'KYDT': 0,
#  'LFCV': 0,
#  'LHKR': 0,
#  'LIVG': 0,
#  'LNEV': 0,
#  'LSED': 0,
#  'LTHL': 0,
#  'LYER': 0,
#  'MDK': 0,
#  'MQRL': 0,
#  'MTS': 0,
#  'MYFL': 0,
#  'NAH': 0,
#  'NEWY': 0,
#  'NKPF': 0,
#  'NRAS': 0,
#  'NTAP': 0,
#  'PCC': 0,
#  'PKLY': 0,
#  'PLLG': 0,
#  'PLPE': 0,
#  'PTW': 0,
#  'PWVQ': 0,
#  'QKN': 0,
#  'QNLA': 0,
#  'QVA': 0,
#  'RSW': 0,
#  'SAED': 0,
#  'SEEG': 0,
#  'SPYD': 0,
#  'SRGA': 0,
#  'SVTM': 0,
#  'SYCE': 0,
#  'TIC': 0,
#  'TLRP': 0,
#  'TQVC': 0,
#  'TTCT': 0,
#  'TVLI': 0,
#  'VDKD': 0,
#  'VGAP': 0,
#  'VRIC': 0,
#  'VRLE': 0,
#  'VTLI': 0,
#  'WKF': 0,
#  'WNPA': 0,
#  'WTQK': 0,
#  'YAYG': 0,
#  'YCMR': 0,
#  'YETR': 0,
#  'YSS': 0}

# %%
with open('output.txt', 'w') as out_file:
    out_file.write(f"#Number of proteins: {total_proteins:>{43}}\n")
    out_file.write(f"#Number of subsequences: {len(subseqdic.keys()):>{39}}\n")
    out_file.write("#Subsequence proportions:\n")
    for subseq, count in sorted_subseqdic.items():
        proportion = round(count / total_proteins, 4)
        out_file.write(f"{subseq:<{15}}{count:>{5}} {proportion:>{19}}\n")

# %%
with open('output.txt', 'w') as out_file:
    out_file.write(f"#Number of proteins: {total_proteins:>{43}}\n")
    out_file.write(f"#Number of subsequences: {len(subseqdic.keys()):>{39}}\n")
    out_file.write("#Subsequence proportions:\n")
    for subseq, count in sorted_subseqdic.items():
        proportion = round(count / total_proteins, 4)
        subseq_formatted = subseq.ljust(19)  # Asegura que subseq ocupe 19 caracteres
        count_formatted = f"{count:>{20 - len(subseq_formatted)}}"
        proportion_formatted = f"{proportion:>{40 - len(subseq_formatted) - len(count_formatted) - 1}}"
        out_file.write(f"{subseq_formatted}{count_formatted}{proportion_formatted}\n")

# %%
with open('output.txt', 'w') as out_file:
    out_file.write(f"#Number of proteins: {total_proteins:>{34}}\n")
    out_file.write(f"#Number of subsequences: {len(subseqdic.keys()):>{30}}\n")
    out_file.write("#Subsequence proportions:\n")
    for subseq, count in sorted_subseqdic.items():
        proportion = round(count / total_proteins, 4)
        subseq_formatted = f"{subseq:<15}"
        count_formatted = f"{count:>4}"
        proportion_formatted = f"{proportion:>9}"
        out_file.write(f"{subseq_formatted}{count_formatted:>20}{proportion_formatted:>20}\n")

# %%
def calculate_aminoacid_frequencies(fasta_filename, subsequences_filename, output_filename, number_of_repetitions=3):

    with open('sequence_fragments.txt', 'r') as file:
        subseqdic = {}
        for line in file:
            subseqdic[line.strip()] = 0

    with open('example_fasta_file.fa', 'r') as fd:
        fastaf = fd.read().split('>')[1:]
        proteins = ["".join(protein.split("\n")[1:]) for protein in fastaf]
    
    for protein in proteins:
        for subseq in subseqdic.keys():
            if protein.count(subseq) >= 3:
                subseqdic[subseq] += 1
    

    total_proteins = len(proteins)

    sorted_subseqdic = dict(sorted(subseqdic.items(), key=lambda x:x[1], reverse=True))

    with open('output.txt', 'w') as out_file:
        out_file.write(f"#Number of proteins: {total_proteins:>{34}}\n")
        out_file.write(f"#Number of subsequences: {len(subseqdic.keys()):>{30}}\n")
        out_file.write("#Subsequence proportions:\n")
        for subseq, count in sorted_subseqdic.items():
            proportion = round(count / total_proteins, 4)
            subseq_formatted = f"{subseq:<15}"
            count_formatted = f"{count:>4}"
            proportion_formatted = f"{proportion:>9}"
            out_file.write(f"{subseq_formatted}{count_formatted:>20}{proportion_formatted:>20}\n")

calculate_aminoacid_frequencies('example_fasta_file.fa', 'sequence_fragments.txt', 'output.txt', 3)
